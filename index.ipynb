# %% [markdown]
# # Join Statements - Lab
#
# ## Introduction
#
# In this lab, you'll practice your knowledge on Join statements.
#
# ## Objectives
#
# You will be able to:
# - Write queries that make use of various types of Joins
# - Join tables using foreign keys

# %% [markdown]
# ## CRM Schema
#
# In almost all cases, rather then just working with a single table we will typically need data from multiple tables.
# Doing this requires the use of **joins ** using shared columns from the two tables.
#
# In this lab, we'll use the same Customer Relationship Management (CRM) database we used in our lecture before!
# <img src='Database-Schema.png' width=550>

# %% [markdown]
# ## Connecting to the Database
# Import the necessary packages and connect to the database **data.sqlite**.

# %%
#Your code here
import sqlite3
conn = sqlite3.connect('data.sqlite')
cursor = conn.cursor()

# %% [markdown]
# ## Display the names of all the employees in Boston.

# %%
#Your code here
cursor.execute("select firstName, lastName, city from employees join offices where city == 'Boston'").fetchall()
# Out:
# [('Diane', 'Murphy', 'Boston'),
#  ('Mary', 'Patterson', 'Boston'),
#  ('Jeff', 'Firrelli', 'Boston'),
#  ('William', 'Patterson', 'Boston'),
#  ('Gerard', 'Bondur', 'Boston'),
#  ('Anthony', 'Bow', 'Boston'),
#  ('Leslie', 'Jennings', 'Boston'),
#  ('Leslie', 'Thompson', 'Boston'),
#  ('Julie', 'Firrelli', 'Boston'),
#  ('Steve', 'Patterson', 'Boston'),
#  ('Foon Yue', 'Tseng', 'Boston'),
#  ('George', 'Vanauf', 'Boston'),
#  ('Loui', 'Bondur', 'Boston'),
#  ('Gerard', 'Hernandez', 'Boston'),
#  ('Pamela', 'Castillo', 'Boston'),
#  ('Larry', 'Bott', 'Boston'),
#  ('Barry', 'Jones', 'Boston'),
#  ('Andy', 'Fixter', 'Boston'),
#  ('Peter', 'Marsh', 'Boston'),
#  ('Tom', 'King', 'Boston'),
#  ('Mami', 'Nishi', 'Boston'),
#  ('Yoshimi', 'Kato', 'Boston'),
#  ('Martin', 'Gerard', 'Boston')]

# %% [markdown]
# ## Do any offices have no employees?

# %%
import pandas as pd

# %%
#Your code here
df = pd.DataFrame(cursor.execute("""select offices.city, Count(*) from offices left join employees using(officeCode) group by offices.officeCode""").fetchall())
df.columns = [i[0] for i in cursor.description]
df
# Out:
#             city  Count(*)
# 0  San Francisco         6
# 1         Boston         2
# 2            NYC         2
# 3          Paris         5
# 4          Tokyo         2
# 5         Sydney         4
# 6         London         2

# %%
df = pd.DataFrame(cursor.execute("""select * from employees order by employees.officeCode""").fetchall())
df.columns = [i[0] for i in cursor.description]
df
# Out:
#    employeeNumber   lastName firstName extension  \
# 0            1002     Murphy     Diane     x5800
# 1            1056  Patterson      Mary     x4611
# 2            1076   Firrelli      Jeff     x9273
# 3            1143        Bow   Anthony     x5428
# 4            1165   Jennings    Leslie     x3291
# 5            1166   Thompson    Leslie     x4065
# 6            1188   Firrelli     Julie     x2173
# 7            1216  Patterson     Steve     x4334
# 8            1286      Tseng  Foon Yue     x2248
# 9            1323     Vanauf    George     x4102
# 10           1102     Bondur    Gerard     x5408
# 11           1337     Bondur      Loui     x6493
# 12           1370  Hernandez    Gerard     x2028
# 13           1401   Castillo    Pamela     x2759
# 14           1702     Gerard    Martin     x2312
# 15           1621      Nishi      Mami      x101
# 16           1625       Kato   Yoshimi      x102
# 17           1088  Patterson   William     x4871
# ...

# %% [markdown]
# ## Write 3 Questions of your own and answer them

# %%
def query_to_df(query):
    df = pd.DataFrame(cursor.execute(query).fetchall())
    df.columns = [i[0] for i in cursor.description]
    return df

# %%
# Answers will vary

# %%
# Your code here

# %%
# Your code here

# %%
# Your code here

# %% [markdown]
# ## Level Up: Display the names of each product each employee has sold.

# %%
#query_to_df("""select * from orderDetails""")
#query_to_df(""" select * from orderDetails join products using(productCode)""")
#query_to_df(""" select * from orderDetails join orders using(orderNumber)""")
#query_to_df("""select customerNumber, customerName, orderNumber from customers join orders using(customerNumber)""")
#query_to_df("""select * from customers join employees on employees.employeeNumber = customers.salesRepEmployeeNumber""")
query_to_df('''select firstName, lastName, productName from employees join customers on employees.employeeNumber = customers.salesRepEmployeeNumber join orders using(customerNumber) join orderdetails using(orderNumber) join products using(productCode)''')
# Out:
#      firstName  lastName                                  productName
# 0       Leslie  Jennings                               1958 Setra Bus
# 1       Leslie  Jennings                       1940 Ford Pickup Truck
# 2       Leslie  Jennings                      1939 Cadillac Limousine
# 3       Leslie  Jennings  1996 Peterbilt 379 Stake Bed with Outrigger
# 4       Leslie  Jennings                            1968 Ford Mustang
# 5       Leslie  Jennings                           1968 Dodge Charger
# 6       Leslie  Jennings                      1970 Plymouth Hemi Cuda
# 7       Leslie  Jennings                           1969 Dodge Charger
# 8       Leslie  Jennings                  1948 Porsche 356-A Roadster
# 9       Leslie  Jennings                         1969 Dodge Super Bee
# 10      Leslie  Jennings                        1976 Ford Gran Torino
# 11      Leslie  Jennings                             1957 Vespa GS150
# ...

# %%
# Your code here

#query_to_df("""select employees.firstName, employees.lastName, products.productName from employees join products""")


# cursor.execute("""select firstName, lastName,
#                       productName
#                       from employees e
#                       join
#                       customers c
#                       on e.employeeNumber = c.salesRepEmployeeNumber
#                       join orders o
#                       using(customerNumber)
#                       join orderdetails od
#                       using(orderNumber)
#                       join products p
#                       using(productCode)""").fetchall()

# %% [markdown]
# ## Level Up: Display the Number of Products each Employee Has sold

# %%
#Your code here

query_to_df('''select firstName, lastName, count(productName) from employees left join customers on employees.employeeNumber = customers.salesRepEmployeeNumber join orders using(customerNumber) join orderdetails using(orderNumber) join products using(productCode) group by firstName, lastName''')
# Out:
#    firstName   lastName  count(productName)
# 0       Andy     Fixter                 185
# 1      Barry      Jones                 220
# 2   Foon Yue      Tseng                 142
# 3     George     Vanauf                 211
# 4     Gerard  Hernandez                 396
# 5      Julie   Firrelli                 124
# 6      Larry       Bott                 236
# 7     Leslie   Jennings                 331
# 8     Leslie   Thompson                 114
# 9       Loui     Bondur                 177
# 10      Mami      Nishi                 137
# 11    Martin     Gerard                 114
# 12    Pamela   Castillo                 272
# 13     Peter      Marsh                 185
# 14     Steve  Patterson                 152

# %% [markdown]
# ## Summary

# %% [markdown]
# Congrats! You now know how to use Join statements, along with leveraging your foreign keys knowledge!
